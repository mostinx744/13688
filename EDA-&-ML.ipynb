# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import warnings
import statistics
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf # Module for the regression
warnings.filterwarnings('ignore')
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
# Predictive Modelling and Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
# Random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
# ARIMA Model
from statsmodels.tsa.arima.model import ARIMA
# Randomized Search
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
# Seasonal time series
from statsmodels.tsa.seasonal import seasonal_decompose
# Decision trees
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
# Cross validation and hyperparameter tuning
from sklearn.model_selection import KFold
# Correlation
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau
from scipy.stats import linregress
# !pip install pd openpyxl
# !pip install xgboost
# !pip install seaborn
# !pip install matplotlib
# !pip install statistics
# !pip install statsmodel
# !pip install pandas
# !pip install scikit-learn
# !pip install linear regression
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement statsmodel (from versions: none)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for statsmodel
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# ...

# %%
df = pd.read_excel('C:/Users/the_m/Downloads/Canadian_Immigration_Dataset.xlsx')
print(df.head())
x=df['Invitations issued']
y=df['CRS score of lowest-ranked candidate invited']
sns.boxplot(x)
plt.show()
sns.scatterplot(x=df['Invitations issued'], y=df['CRS score of lowest-ranked candidate invited'])
sns.violinplot(x=df['Invitations issued'], y=df['CRS score of lowest-ranked candidate invited'])
plt.show()
plt.figure(figsize=(10,6))
print("mean value of x:", statistics.mean(x))
print("mean value np of x:", np.mean(x))
print("mean value of y:", statistics.mean(y))
print("mean value np of y:", np.mean(y))
print("median value of x:", statistics.median(x))
print("median value np of x:", np.median(x))
print("median value of y:", statistics.median(y))
print("median value of np y:", np.median(y))
print("mode_value_x:",statistics.mode(x))
print("mode_value_y:",statistics.mode(y))
x=df['Invitations issued']
y=df['CRS score of lowest-ranked candidate invited']
z=df['Date']
# Correlation of three
print("Pearson:", pearsonr(x, y))
print("Spearman:", spearmanr(x, y))
print("Kendall:", kendalltau(x, y))

x=df['Invitations issued']
y=df['CRS score of lowest-ranked candidate invited']
# Hypothesis testing for one sample
result_x = stats.ttest_1samp(x, popmean=3000)
result_y = stats.ttest_1samp(y, popmean=400)
# Hypothesis testing for two
result = stats.ttest_ind(x, y)
print(result)
# Predictive Modelling and Machine Learning
# Linear Regression
fit1 = linregress(x, y)
y_pred = fit1.intercept + fit1.slope * x
plt.scatter(x, y, color='blue', label='Data points')
# Random Forest Classifier

# Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Create a random classifier (uniform random predictions)
clf = DummyClassifier(strategy="uniform", random_state=42)
clf.fit(x_train, y_train)

# Predictions
y_pred = clf.predict(x_test)

# Accuracy
print("Random Classifier Accuracy:", accuracy_score(y_test, y_pred))
# Xgboost
# Split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=42)
# Convert data to DMatrix (optimized data structure for XGBoost)
dtrain = xgb.DMatrix(x_train, label=y_train)
dtest = xgb.DMatrix(x_test, label=y_test)
# Set parameters for the model
params = {
   "objective": "reg:squarederror", # Regression task
   "max_depth": 3,
   "eta": 0.35,
   "seed": 42
}
# Train the model
num_round = 50
model = xgb.train(params, dtrain, num_boost_round=num_round)
# Make predictions
predictions = model.predict(dtest)
# Evaluate the model
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"RMSE: {rmse}")
# Time series ARIMA models
model = ARIMA(df['Invitations issued'], order=(5,1,0))
model_fit = model.fit()
forecast = model_fit.forecast(steps=12)
print(forecast)

# R Squared
import numpy as np
from scipy import stats

# Perform linear regression
slope, intercept, r_value, p_value, std_err = stats.linregress(x, y)

# Calculate R-squared
r_squared = r_value**2

print(f"Slope: {slope:.4f}")
print(f"Intercept: {intercept:.4f}")
print(f"R-squared: {r_squared:.4f}")
# Mae
-
# Out:
#    Unnamed: 0  Draw Number       Date         Immigration program  \
# 0           0          172 2021-01-07   Canadian Experience Class
# 1           1          171 2021-01-06  Provincial Nominee Program
# 2           2          170 2020-12-23        No program specified
# 3           3          169 2020-12-09        No program specified
# 4           4          168 2020-11-25        No program specified
#
#    Invitations issued  CRS score of lowest-ranked candidate invited  \
# 0                4750                                           461
# 1                 250                                           813
# 2                5000                                           468
# 3                5000                                           469
# 4                5000                                           469
#
#   Date (hidden)                                   Programs covered  Month  \
# 0    2021-07-01                          Canadian Experience Class      1
# ...
